# %%
import numpy as np
import cv2 as cv
import matplotlib
import numpy as np
import pywt
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#croping of  the facial region of the image

# %%
face_cascade = cv.CascadeClassifier('./Haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv.CascadeClassifier('./Haarcascades/haarcascade_eye.xml')

# %%
def get_cropped_image_if_2_eyes(image_path):

    img = cv.imread(image_path)
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
c_img = cv.imread('./test_image/02453493f852c0efe8ff951dea5845c4.jpg')
plt.imshow(c_img)

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 cropped_image = get_cropped_image_if_2_eyes('./test_images/MESSI.jpp')
#       2 plt.imshow(cropped_image)
#
# Cell In[12], line 4, in get_cropped_image_if_2_eyes(image_path)
#       1 def get_cropped_image_if_2_eyes(image_path):
#       3     img = cv.imread(image_path)
# ----> 4     gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
#       5     faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#       6     for (x,y,w,h) in faces:
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv.cvtColor( imArray,cv.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(c_img,'db1',5)
plt.imshow(im_har, cmap='gray')
