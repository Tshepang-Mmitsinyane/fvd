# %%
import numpy as np 
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
matches = pd.read_csv('matches.csv', index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# ...

# %% [markdown]
# # Data Cleaning

# %%
matches.shape
# Out:
# (1389, 27)

# %% [markdown]
# The Premier League has about 38 matches every season and has 20 team in the league. Our data has Premier league match data for 2 seasons. Therefore we should have about 1580 matches, but how dataset has less.

# %%
matches['team'].value_counts()
# Out:
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: team, dtype: int64

# %% [markdown]
# In the premier league / EPL every season there are 3 teams that relegated. Therefore we should have 6 teams with less than 70 matches, however we have 7. Note that liverpool is among the teams that have less than 70 matches, but was not regelated last season.

# %%
matches[matches['team'] == 'Liverpool']
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W  4.0
# 2   2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 4   2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W  3.0
# 6   2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 7   2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# 9   2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 11  2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W  2.0
# 13  2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D  1.0
# 14  2020-11-22  19:15  Premier League   Matchweek 9  Sun  Home      W  3.0
# 16  2020-11-28  12:30  Premier League  Matchweek 10  Sat  Away      D  1.0
# 18  2020-12-06  19:15  Premier League  Matchweek 11  Sun  Home      W  4.0
# ...

# %% [markdown]
# Looking at dataframe, it seems that we are missing datafor one season of macthes liverpool.

# %%
matches['round'].value_counts()
# Out:
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
# convert the date column into a date time.
matches['date'] = pd.to_datetime(matches['date'])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
# add a new column that will convert the the venue column to integers, so that we can use the variable in our model.
matches['venue_code'] = matches['venue'].astype('category').cat.codes

# %%
matches.head()
# Out:
#         date   time        round  day venue result   gf   ga        opponent  \
# 1 2021-08-15  16:30  Matchweek 1  Sun  Away      L  0.0  1.0       Tottenham
# 2 2021-08-21  15:00  Matchweek 2  Sat  Home      W  5.0  0.0    Norwich City
# 3 2021-08-28  12:30  Matchweek 3  Sat  Home      W  5.0  0.0         Arsenal
# 4 2021-09-11  15:00  Matchweek 4  Sat  Away      W  1.0  0.0  Leicester City
# 6 2021-09-18  15:00  Matchweek 5  Sat  Home      D  0.0  0.0     Southampton
#
#     xg  ...  match report    sh   sot  dist   fk   pk pkatt  season  \
# 1  1.9  ...  Match Report  18.0   4.0  16.9  1.0  0.0   0.0    2022
# 2  2.7  ...  Match Report  16.0   4.0  17.3  1.0  0.0   0.0    2022
# 3  3.8  ...  Match Report  25.0  10.0  14.3  0.0  0.0   0.0    2022
# 4  2.9  ...  Match Report  25.0   8.0  14.0  0.0  0.0   0.0    2022
# 6  1.1  ...  Match Report  16.0   1.0  15.7  1.0  0.0   0.0    2022
#
#               team  venue_code
# 1  Manchester City           0
# ...

# %%
# convet the opponents column into numerical values.
matches['opp_code'] = matches['opponent'].astype('category').cat.codes

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2021-08-15  16:30   Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00   Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30   Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 38 2021-05-02  19:15  Matchweek 34  Sun  Away      L  0.0  4.0
# 39 2021-05-08  15:00  Matchweek 35  Sat  Home      L  0.0  2.0
# 40 2021-05-16  19:00  Matchweek 36  Sun  Away      W  1.0  0.0
# 41 2021-05-19  18:00  Matchweek 37  Wed  Away      L  0.0  1.0
# 42 2021-05-23  16:00  Matchweek 38  Sun  Home      W  1.0  0.0
#
#           opponent   xg  ...    sh   sot  dist   fk   pk pkatt season  \
# 1        Tottenham  1.9  ...  18.0   4.0  16.9  1.0  0.0   0.0   2022
# ...

# %%
# we just want the hour the matche was played, therefore we shall remove the minutes in the time.
matches['hour'] = matches['time'].str.replace(":.+","",regex=True).astype('int')

# %%
matches.head()
# Out:
#         date   time        round  day venue result   gf   ga        opponent  \
# 1 2021-08-15  16:30  Matchweek 1  Sun  Away      L  0.0  1.0       Tottenham
# 2 2021-08-21  15:00  Matchweek 2  Sat  Home      W  5.0  0.0    Norwich City
# 3 2021-08-28  12:30  Matchweek 3  Sat  Home      W  5.0  0.0         Arsenal
# 4 2021-09-11  15:00  Matchweek 4  Sat  Away      W  1.0  0.0  Leicester City
# 6 2021-09-18  15:00  Matchweek 5  Sat  Home      D  0.0  0.0     Southampton
#
#     xg  ...   sot  dist   fk   pk pkatt season             team  venue_code  \
# 1  1.9  ...   4.0  16.9  1.0  0.0   0.0   2022  Manchester City           0
# 2  2.7  ...   4.0  17.3  1.0  0.0   0.0   2022  Manchester City           1
# 3  3.8  ...  10.0  14.3  0.0  0.0   0.0   2022  Manchester City           1
# 4  2.9  ...   8.0  14.0  0.0  0.0   0.0   2022  Manchester City           0
# 6  1.1  ...   1.0  15.7  1.0  0.0   0.0   2022  Manchester City           1
#
#    opp_code  hour
# 1        18    16
# ...

# %%
# we convert the date in the week into numerical values
matches['day_code'] = matches['date'].dt.dayofweek

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2021-08-15  16:30   Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00   Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30   Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 38 2021-05-02  19:15  Matchweek 34  Sun  Away      L  0.0  4.0
# 39 2021-05-08  15:00  Matchweek 35  Sat  Home      L  0.0  2.0
# 40 2021-05-16  19:00  Matchweek 36  Sun  Away      W  1.0  0.0
# 41 2021-05-19  18:00  Matchweek 37  Wed  Away      L  0.0  1.0
# 42 2021-05-23  16:00  Matchweek 38  Sun  Home      W  1.0  0.0
#
#           opponent   xg  ...  dist   fk   pk pkatt season              team  \
# 1        Tottenham  1.9  ...  16.9  1.0  0.0   0.0   2022   Manchester City
# ...

# %%
# convert result column into integars. if the teeam loses and draws the result is 0 and if the win the result is 1.
matches['results'] = (matches['result'] == 'W').astype('int')

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2021-08-15  16:30   Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00   Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30   Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 38 2021-05-02  19:15  Matchweek 34  Sun  Away      L  0.0  4.0
# 39 2021-05-08  15:00  Matchweek 35  Sat  Home      L  0.0  2.0
# 40 2021-05-16  19:00  Matchweek 36  Sun  Away      W  1.0  0.0
# 41 2021-05-19  18:00  Matchweek 37  Wed  Away      L  0.0  1.0
# 42 2021-05-23  16:00  Matchweek 38  Sun  Home      W  1.0  0.0
#
#           opponent   xg  ...   fk   pk  pkatt season              team  \
# 1        Tottenham  1.9  ...  1.0  0.0    0.0   2022   Manchester City
# ...

# %% [markdown]
# # Splitting our data

# %%
# X=matches[["venue_code", "opp_code", "hour", "day_code"]]
# y= matches['results']
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
train_set = matches[matches["date"] < '2022-01-01']

# %%
test_set= matches[matches["date"] > '2022-01-01']

# %%
X = ["venue_code", "opp_code", "hour", "day_code"]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
rf.fit(train_set[X], train_set["results"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
predictions = rf.predict(test_set[X])

# %%
from sklearn.metrics import accuracy_score

# %%
accur = accuracy_score(test_test["results"], predictions)

# %%
accur
# Out:
# 0.6123188405797102

# %%
combined = pd.DataFrame(dict(actual=test['results'], prediction = predictions))

# %%
pd.crosstab(index=combined['actual'], columns=combined['prediction'])
# Out:
# prediction    0   1
# actual
# 0           141  31
# 1            76  28

# %%
# when we predicted a loss or a draw, most of the time we were correct. When predicting a win we often a times wrong.

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test['results'], predictions)
# Out:
# 0.4745762711864407

# %%
grouped_matches = matches.groupby('team')

# %%
group = grouped_matches.get_group('Arsenal')

# %%
group
# Out:
#          date   time         round  day venue result   gf   ga  \
# 0  2021-08-13  20:00   Matchweek 1  Fri  Away      L  0.0  2.0
# 1  2021-08-22  16:30   Matchweek 2  Sun  Home      L  0.0  2.0
# 3  2021-08-28  12:30   Matchweek 3  Sat  Away      L  0.0  5.0
# 4  2021-09-11  15:00   Matchweek 4  Sat  Home      W  1.0  0.0
# 5  2021-09-18  15:00   Matchweek 5  Sat  Away      W  1.0  0.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 52 2021-05-02  14:00  Matchweek 34  Sun  Away      W  2.0  0.0
# 54 2021-05-09  19:00  Matchweek 35  Sun  Home      W  3.0  1.0
# 55 2021-05-12  20:15  Matchweek 36  Wed  Away      W  1.0  0.0
# 56 2021-05-19  19:00  Matchweek 37  Wed  Away      W  3.0  1.0
# 57 2021-05-23  16:00  Matchweek 38  Sun  Home      W  2.0  0.0
#
#            opponent   xg  ...   fk   pk  pkatt season     team venue_code  \
# 0         Brentford  1.4  ...  1.0  0.0    0.0   2022  Arsenal          0
# ...
